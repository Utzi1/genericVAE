# %%
pip install jupyterlab-spellchecker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 10.4 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
#   Using cached y_py-0.5.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
# ...
#   Using cached ypy_websocket-0.8.3-py3-none-any.whl (10 kB)
#   Using cached ypy_websocket-0.8.2-py3-none-any.whl (10 kB)
# ...
#   Using cached aiofiles-22.1.0-py3-none-any.whl (14 kB)
# ...
#   Attempting uninstall: y-py
#     Found existing installation: y-py 0.6.0
#     Uninstalling y-py-0.6.0:
#       Successfully uninstalled y-py-0.6.0
#   Attempting uninstall: jupyter-ydoc
#     Found existing installation: jupyter-ydoc 1.0.0
#     Uninstalling jupyter-ydoc-1.0.0:
#       Successfully uninstalled jupyter-ydoc-1.0.0
#   Attempting uninstall: aiofiles
#     Found existing installation: aiofiles 23.1.0
#     Uninstalling aiofiles-23.1.0:
#       Successfully uninstalled aiofiles-23.1.0
# ...
